# %% [markdown]
# # Self-Driving Car Engineer Nanodegree
#
# ## Deep Learning
#
# ## Project: Build a Traffic Sign Recognition Classifier
#
# In this notebook, a template is provided for you to implement your functionality in stages, which is required to successfully complete this project. If additional code is required that cannot be included in the notebook, be sure that the Python code is successfully imported and included in your submission if necessary.
#
# > **Note**: Once you have completed all of the code implementations, you need to finalize your work by exporting the iPython Notebook as a Jupyter notebook document. Before exporting the notebook to ipynb, all of the code cells need to have been run so that reviewers can see the final implementation and output. You can then export the notebook by using the menu above and navigating to  \n",
#     "**File -> Download as -> Notebook (.ipynb)**. Include the finished document along with this notebook as your submission.
#
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut. In addition, Markdown cells can be edited by typically double-clicking the cell to enter edit mode.

# %%
#@title Run Me Please
# !pip -q install pydot_ng
# !pip -q install graphviz
# !apt install graphviz > /dev/null

from __future__ import absolute_import, division, print_function

import tensorflow as tf
# import tensorflow.contrib.eager as tfe
import numpy as np
import matplotlib.pyplot as plt
from IPython import display
# %matplotlib inline
from tensorflow import keras
# try:
#   tf.enable_eager_execution()
#   print('Running in Eager mode.')
# except ValueError:
#   print('Already running in Eager mode')

from __future__ import print_function, division
from builtins import range, input
from keras.layers import Input, Lambda, Dense, Flatten, Dropout, AveragePooling2D, Rescaling, Conv2D
from keras.models import Model, Sequential, load_model
from keras.applications.vgg16 import VGG16
from keras.applications import VGG19
from keras.applications import ResNet50
# from tensorflow.keras.applications.inception_v3 import inception_v3
from tensorflow.keras.applications.inception_v3 import InceptionV3
from keras.applications.vgg16 import preprocess_input
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.vis_utils import plot_model
# from tensorflow.contrib.layers import flatten

from sklearn.metrics import confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
from time import time
import pickle
from sklearn.utils import shuffle

# Feel free to import more packages
import pandas as pd
import random
import seaborn as sns

# %% [markdown]
# ---
# ## Step 0: Load The Data

# %%
# Load pickled data

# TODO: Fill this in based on where you saved the training and testing data
# If you have a folder in your Drive named traffic-signs-data you do so, else change directory

# training_file = '/content/gdrive/My Drive/traffic-signs-data/train.p'
# validation_file = '/content/gdrive/My Drive/traffic-signs-data/valid.p'
# testing_file = '/content/gdrive/My Drive/traffic-signs-data/test.p'

training_file = 'train.p'
validation_file= 'valid.p'
testing_file = 'test.p'

with open(training_file, mode='rb') as f:
    train = pickle.load(f)
with open(validation_file, mode='rb') as f:
    valid = pickle.load(f)
with open(testing_file, mode='rb') as f:
    test = pickle.load(f)

# %% [markdown]
# ---
#
# ## Step 1: Dataset Summary & Exploration
#
# The pickled data is a dictionary with 4 key/value pairs:
#
# - `'features'` is a 4D array containing raw pixel data of the traffic sign images, (num examples, width, height, channels).
# - `'labels'` is a 1D array containing the label/class id of the traffic sign. The file `signnames.csv` contains id -> name mappings for each id.
# - `'sizes'` is a list containing tuples, (width, height) representing the original width and height the image.
# - `'coords'` is a list containing tuples, (x1, y1, x2, y2) representing coordinates of a bounding box around the sign in the image. **THESE COORDINATES ASSUME THE ORIGINAL IMAGE. THE PICKLED DATA CONTAINS RESIZED VERSIONS (32 by 32) OF THESE IMAGES**
#
# Complete the basic data summary below. Use python, numpy and/or pandas methods to calculate the data summary rather than hard coding the results. For example, the [pandas shape method](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.shape.html) might be useful for calculating some of the summary results.

# %%
# Please complete None with your code
#-------------------------------------------------------------------------
signs = []
signnames = pd.read_csv('signnames.csv', delimiter=',', header=0)
for row in range(signnames.shape[0]):
     signs.append(signnames.iloc[row, 1])    
    
X_train, y_train = train['features'], train['labels']
X_valid, y_valid = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %% [markdown]
# ### Provide a Basic Summary of the Data Set Using Python, Numpy and/or Pandas

# %%
# Please complete None with your code
#-------------------------------------------------------------------------
#  Number of training examples
n_train = X_train.shape[0]

# Number of validation examples
n_validation = X_valid.shape[0]

# Number of test examples.
n_test = X_test.shape[0]

#  What's the shape of a traffic sign image?
image_shape = X_test[0].shape

#  How many unique classes/labels there are in the dataset.
n_classes = len(set(y_train))


print("Number of training examples =", n_train)
print("Number of testing examples =", n_test)
print("Number of valid examples =", n_validation)
print("Image data shape =", image_shape)
print("Number of classes =", n_classes)
# Out:
# Number of training examples = 34799
# Number of testing examples = 12630
# Number of valid examples = 4410
# Image data shape = (32, 32, 3)
# Number of classes = 43

# %% [markdown]
# ### Include an exploratory visualization of the dataset

# %% [markdown]
# Visualize the German Traffic Signs Dataset using the pickled file(s). This is open ended, suggestions include: plotting traffic sign images, plotting the count of each sign, etc.
#
# The [Matplotlib](http://matplotlib.org/) [examples](http://matplotlib.org/examples/index.html) and [gallery](http://matplotlib.org/gallery.html) pages are a great resource for doing visualizations in Python.
#
# **NOTE:** It's recommended you start with something simple first. If you wish to do more, come back to it after you've completed the rest of the sections. It can be interesting to look at the distribution of classes in the training, validation and test set. Is the distribution the same? Are there more examples of some classes than others?

# %%
### Data exploration visualization code goes here.
import matplotlib.pyplot as plt
# Visualizations will be shown in the notebook.
# %matplotlib inline
def show_images(X,Y,r,c):
    fig, axs = plt.subplots(r,c, figsize=(15, 6))
    fig.subplots_adjust(hspace = .2, wspace=.001)
    axs = axs.ravel()
    for i in range(r*c): # if rows = 2 and columns = 5 i should take 10 values
        index = random.randint(0, len(X))
        image = X[index]
        axs[i].axis('off')
        axs[i].imshow(image)
        axs[i].set_title(Y[index])
    plt.show()    

# show image of 10 random data points
rows = 2
columns = 5
show_images (X_train, y_train, rows, columns)

# %%
plt.figure(figsize=(20,5))
item, count = np.unique(y_train, return_counts=True)
#names is a list of traffic signs, Remember that we already have a list : signs
names = signs
y_pos = np.arange(len(names))
plt.bar(item, count, alpha=0.6, color = (0.3,0.9,0.4,0.6) )

plt.xticks(y_pos, names, fontsize=15, rotation=90)

plt.show()

# %%
plt.figure(figsize=(20,5))
item, count = np.unique(y_test, return_counts=True)
item1, count1 = np.unique(y_valid, return_counts=True)

names = signs
names1 = signs

y_pos = np.arange(len(names))
plt.bar(item, count, alpha=0.6, color = (0.3,0.5,0.4,0.2), label="Validation Data" )

plt.bar(item1, count1, alpha=0.6, color = (0.9,0.1,0.3,0.2), label="Train Data" )

plt.xticks(y_pos, names, fontsize=15, rotation=90)
plt.legend()
plt.show()

# %% [markdown]
# ----
#
# ## Step 2: Design and Test a Model Architecture
#
# Design and implement a deep learning model that learns to recognize traffic signs. Train and test your model on the [German Traffic Sign Dataset](http://benchmark.ini.rub.de/?section=gtsrb&subsection=dataset).
#
# The LeNet-5 implementation shown in the [classroom](https://classroom.udacity.com/nanodegrees/nd013/parts/fbf77062-5703-404e-b60c-95b78b2f3f9e/modules/6df7ae49-c61c-4bb2-a23e-6527e69209ec/lessons/601ae704-1035-4287-8b11-e2c2716217ad/concepts/d4aca031-508f-4e0b-b493-e7b706120f81) at the end of the CNN lesson is a solid starting point. You'll have to change the number of classes and possibly the preprocessing, but aside from that it's plug and play!
#
# With the LeNet-5 solution from the lecture, you should expect a validation set accuracy of about 0.89. To meet specifications, the validation set accuracy will need to be at least 0.93. It is possible to get an even higher accuracy, but 0.93 is the minimum for a successful project submission.
#
# There are various aspects to consider when thinking about this problem:
#
# - Neural network architecture (is the network over or underfitting?)
# - Play around preprocessing techniques (normalization, rgb to grayscale, etc)
# - Number of examples per label (some have more than others).
# - Generate fake data.
#
# Here is an example of a [published baseline model on this problem](http://yann.lecun.com/exdb/publis/pdf/sermanet-ijcnn-11.pdf). It's not required to be familiar with the approach used in the paper but, it's good practice to try to read papers like these.

# %% [markdown]
# ### Pre-process the Data Set (normalization, grayscale, etc.)

# %% [markdown]
# Minimally, the image data should be normalized so that the data has mean zero and equal variance. For image data, `(pixel - 128)/ 128` is a quick way to approximately normalize the data and can be used in this project.
#
# Other pre-processing steps are optional. You can try different techniques to see if it improves performance.
#
# Use the code cell (or multiple code cells, if necessary) to implement the first step of your project.

# %%
# gray scale
X_test_gry = np.sum(X_test/3, axis=3, keepdims=True)
X_train_gry = np.sum(X_train/3, axis=3, keepdims=True)
X_valid_gry = np.sum(X_valid/3, axis=3, keepdims=True)

# %%
# normalization Here
X_train = np.array([(sign - 128.) / 128. for sign in X_train])
X_test = np.array([(sign - 128.) / 128. for sign in X_test])
X_valid = np.array([(sign - 128.) / 128. for sign in X_valid])

# %%
# Shuffle your data here
X_train, y_train = shuffle(X_train, y_train)
X_valid, y_valid = shuffle(X_valid, y_valid)
X_test, y_test = shuffle(X_test, y_test)

# %%
import cv2

def random_translate(img):
    rows,cols,_ = img.shape
    
    # allow translation up to px pixels in x and y directions
    px = 2
    dx,dy = np.random.randint(-px,px,2)

    M = np.float32([[1,0,dx],[0,1,dy]])
    dst = cv2.warpAffine(img,M,(cols,rows))
    
    dst = dst[:,:,np.newaxis]
    
    return dst

# %% [markdown]
# Next cells should be useful for data augmentation

# %%
def random_scaling(img):   
    rows,cols,_ = img.shape

    # transform limits
    px = np.random.randint(-2,2)

    # ending locations
    pts1 = np.float32([[px,px],[rows-px,px],[px,cols-px],[rows-px,cols-px]])

    # starting locations (4 corners)
    pts2 = np.float32([[0,0],[rows,0],[0,cols],[rows,cols]])

    M = cv2.getPerspectiveTransform(pts1,pts2)

    dst = cv2.warpPerspective(img,M,(rows,cols))
    
    dst = dst[:,:,np.newaxis]
    
    return dst

# %%
def random_warp(img):
    rows,cols,_ = img.shape

    # random scaling coefficients
    rndx = np.random.rand(3) - 0.5
    rndx *= cols * 0.06   # this coefficient determines the degree of warping
    rndy = np.random.rand(3) - 0.5
    rndy *= rows * 0.06

    # 3 starting points for transform, 1/4 way from edges
    x1 = cols/4
    x2 = 3*cols/4
    y1 = rows/4
    y2 = 3*rows/4

    pts1 = np.float32([[y1,x1],
                       [y2,x1],
                       [y1,x2]])
    pts2 = np.float32([[y1+rndy[0],x1+rndx[0]],
                       [y2+rndy[1],x1+rndx[1]],
                       [y1+rndy[2],x2+rndx[2]]])

    M = cv2.getAffineTransform(pts1,pts2)

    dst = cv2.warpAffine(img,M,(cols,rows))
    
    dst = dst[:,:,np.newaxis]
    
    return dst

# %%
def random_brightness(img):
    shifted = img + 1.0   # shift to (0,2) range
    img_max_value = max(shifted.flatten())
    max_coef = 2.0/img_max_value
    min_coef = max_coef - 0.1
    coef = np.random.uniform(min_coef, max_coef)
    dst = shifted * coef - 1.0
    return dst

# %%
# Data augmentation 
# This may take too much time...
# i've set 2000 as a minimum number of images for each class
# if u don't already have a file containing generated Data, Run ME please
# --------------------------!!!!-----------------------------------------

# input_indices = []
# output_indices = []
# # new_X_train = X_train

# for class_n in range(n_classes):
#     class_indices = np.where(y_train == class_n)
#     n_samples = len(class_indices[0])
#     if n_samples < 2000:
#         for i in range(2000 - n_samples):
#             input_indices.append(class_indices[0][i%n_samples])
#             output_indices.append(new_X_train.shape[0])
#             new_img = new_X_train[class_indices[0][i % n_samples]]
#             new_img = random_translate(random_scaling(random_warp(random_brightness(new_img))))
#             new_X_train = np.concatenate((new_X_train, [new_img]), axis=0)
#             y_train = np.concatenate((y_train, [class_n]), axis=0)
# data_file = "new_train.p"
# pickle.dump({"images":new_X_train,"labels":y_train},open(data_file,"wb"),protocol=4)

# %%
# if u do have a file that contains new_train data RUN ME
# with open("new_train.p","rb") as f:
#     data = pickle.load(f)
# new_X_train,y_train = data["images"],data["labels"]

# %%
new_X_train = X_train

# %%
def plot_figures_no_labels(figures, nrows = 1, ncols=1):
    fig, axs = plt.subplots(ncols=ncols, nrows=nrows, figsize=(15, 15))
    axs = axs.ravel()
    for index, title in zip(range(len(figures)), figures):
        axs[index].imshow(figures[title], plt.gray())
        axs[index].set_axis_off()
        
    plt.tight_layout()
    plt.show()
    
for class_n in range(n_classes): # you should range for all classes 
    figures = {}

    class_indices = list (np.where(y_train == class_n)[0])
  
    for i in range(8):
    
        figures[i] = ((new_X_train[class_indices[-i]]+1.)/2.).squeeze()
      
    plot_figures_no_labels(figures, 1, 8)

# %%
plt.figure(figsize=(20,5))
item, count = np.unique(y_train, return_counts=True)
names = signs
y_pos = np.arange(len(names))
plt.bar(item, count, alpha=0.6, color = (0.9,0.3,0.4,0.6) )
plt.xticks(y_pos, names, fontsize=15, rotation=90)
plt.show()

# %%
# In this part you should One-hot encode all Y-s vectors using
y_train = pd.get_dummies(y_train).values
y_test = pd.get_dummies(y_test).values
y_valid = pd.get_dummies(y_valid).values

# %% [markdown]
# ### Model Architecture

# %%
IMAGE_SIZE = [32, 32]
epochs = 100
batch_size = 64
image_input = Input(shape=(32, 32, 1))

# %%
# Feel free to use as many code cells as needed.

# %%
# define your model
# Use pretrained model

# %%
model = Sequential([
    Rescaling(1, input_shape=(32, 32, 3)),
    Conv2D(6, kernel_size=(5, 5), activation='relu'),
    AveragePooling2D(pool_size=(2, 2)),
    Conv2D(16, kernel_size=(5, 5), activation='relu'),
    AveragePooling2D(pool_size=(2, 2)),
    Conv2D(120, kernel_size=(5, 5), activation='relu'),
    Dropout(0.2),
    Flatten(),
    Dense(120, activation='relu'),
    Dense(43, activation='softmax')
])

# Compilation of the model
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Model architecture
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 32, 32, 3)         0
#
#  conv2d (Conv2D)             (None, 28, 28, 6)         456
#
#  average_pooling2d (AverageP  (None, 14, 14, 6)        0
#  ooling2D)
#
#  conv2d_1 (Conv2D)           (None, 10, 10, 16)        2416
#
#  average_pooling2d_1 (Averag  (None, 5, 5, 16)         0
#  ePooling2D)
#
#  conv2d_2 (Conv2D)           (None, 1, 1, 120)         48120
#
#  dropout (Dropout)           (None, 1, 1, 120)         0
#
#  flatten (Flatten)           (None, 120)               0
#
#  dense (Dense)               (None, 120)               14520
#
#  dense_1 (Dense)             (None, 43)                5203
#
# =================================================================
# Total params: 70,715
# Trainable params: 70,715
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train, Validate and Test the Model

# %%
#Training
history = model.fit(X_train, y_train, epochs = epochs, batch_size = batch_size, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/100
# 544/544 [==============================] - 7s 13ms/step - loss: 1.6384 - accuracy: 0.5365 - val_loss: 0.7126 - val_accuracy: 0.7680
# Epoch 2/100
# 544/544 [==============================] - 7s 12ms/step - loss: 0.4844 - accuracy: 0.8515 - val_loss: 0.4688 - val_accuracy: 0.8560
# Epoch 3/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.2871 - accuracy: 0.9137 - val_loss: 0.3460 - val_accuracy: 0.8964
# Epoch 4/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.1967 - accuracy: 0.9411 - val_loss: 0.3369 - val_accuracy: 0.8937
# Epoch 5/100
# 544/544 [==============================] - 7s 12ms/step - loss: 0.1504 - accuracy: 0.9550 - val_loss: 0.3309 - val_accuracy: 0.9073
# Epoch 6/100
# 544/544 [==============================] - 7s 12ms/step - loss: 0.1199 - accuracy: 0.9644 - val_loss: 0.3187 - val_accuracy: 0.9166
# Epoch 7/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.1011 - accuracy: 0.9693 - val_loss: 0.2837 - val_accuracy: 0.9206
# Epoch 8/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0844 - accuracy: 0.9743 - val_loss: 0.2928 - val_accuracy: 0.9231
# Epoch 9/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0732 - accuracy: 0.9771 - val_loss: 0.3002 - val_accuracy: 0.9299
# Epoch 10/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0645 - accuracy: 0.9792 - val_loss: 0.3010 - val_accuracy: 0.9188
# Epoch 11/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0575 - accuracy: 0.9826 - val_loss: 0.3749 - val_accuracy: 0.9170
# Epoch 12/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0560 - accuracy: 0.9821 - val_loss: 0.3541 - val_accuracy: 0.9304
# Epoch 13/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0463 - accuracy: 0.9856 - val_loss: 0.3168 - val_accuracy: 0.9245
# Epoch 14/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0476 - accuracy: 0.9847 - val_loss: 0.3267 - val_accuracy: 0.9281
# Epoch 15/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0424 - accuracy: 0.9865 - val_loss: 0.3021 - val_accuracy: 0.9281
# Epoch 16/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0379 - accuracy: 0.9881 - val_loss: 0.3964 - val_accuracy: 0.9238
# Epoch 17/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0377 - accuracy: 0.9880 - val_loss: 0.3011 - val_accuracy: 0.9306
# Epoch 18/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0375 - accuracy: 0.9887 - val_loss: 0.3373 - val_accuracy: 0.9299
# Epoch 19/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0299 - accuracy: 0.9902 - val_loss: 0.3177 - val_accuracy: 0.9327
# Epoch 20/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0335 - accuracy: 0.9889 - val_loss: 0.3263 - val_accuracy: 0.9361
# Epoch 21/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0274 - accuracy: 0.9913 - val_loss: 0.2742 - val_accuracy: 0.9397
# Epoch 22/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0304 - accuracy: 0.9907 - val_loss: 0.3242 - val_accuracy: 0.9351
# Epoch 23/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0284 - accuracy: 0.9908 - val_loss: 0.3600 - val_accuracy: 0.9295
# Epoch 24/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0278 - accuracy: 0.9906 - val_loss: 0.3976 - val_accuracy: 0.9331
# Epoch 25/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0269 - accuracy: 0.9908 - val_loss: 0.2692 - val_accuracy: 0.9417
# Epoch 26/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0291 - accuracy: 0.9908 - val_loss: 0.3292 - val_accuracy: 0.9372
# Epoch 27/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0244 - accuracy: 0.9924 - val_loss: 0.3661 - val_accuracy: 0.9333
# Epoch 28/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0257 - accuracy: 0.9922 - val_loss: 0.2881 - val_accuracy: 0.9408
# Epoch 29/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0227 - accuracy: 0.9929 - val_loss: 0.3683 - val_accuracy: 0.9290
# Epoch 30/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0207 - accuracy: 0.9934 - val_loss: 0.3921 - val_accuracy: 0.9390
# Epoch 31/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0254 - accuracy: 0.9922 - val_loss: 0.3891 - val_accuracy: 0.9347
# Epoch 32/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0223 - accuracy: 0.9928 - val_loss: 0.3489 - val_accuracy: 0.9356
# Epoch 33/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0206 - accuracy: 0.9939 - val_loss: 0.4172 - val_accuracy: 0.9299
# Epoch 34/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0175 - accuracy: 0.9943 - val_loss: 0.3561 - val_accuracy: 0.9361
# Epoch 35/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0263 - accuracy: 0.9920 - val_loss: 0.4441 - val_accuracy: 0.9329
# Epoch 36/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0230 - accuracy: 0.9929 - val_loss: 0.4434 - val_accuracy: 0.9354
# Epoch 37/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0196 - accuracy: 0.9939 - val_loss: 0.6580 - val_accuracy: 0.9358
# Epoch 38/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0187 - accuracy: 0.9941 - val_loss: 0.4645 - val_accuracy: 0.9392
# Epoch 39/100
# 544/544 [==============================] - 7s 14ms/step - loss: 0.0180 - accuracy: 0.9946 - val_loss: 0.5680 - val_accuracy: 0.9243
# Epoch 40/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0162 - accuracy: 0.9946 - val_loss: 0.5202 - val_accuracy: 0.9385
# Epoch 41/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0209 - accuracy: 0.9935 - val_loss: 0.5167 - val_accuracy: 0.9317
# Epoch 42/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0157 - accuracy: 0.9951 - val_loss: 0.3352 - val_accuracy: 0.9381
# Epoch 43/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0154 - accuracy: 0.9957 - val_loss: 0.3696 - val_accuracy: 0.9395
# Epoch 44/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0190 - accuracy: 0.9934 - val_loss: 0.4018 - val_accuracy: 0.9385
# Epoch 45/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0188 - accuracy: 0.9941 - val_loss: 0.5105 - val_accuracy: 0.9483
# Epoch 46/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0158 - accuracy: 0.9954 - val_loss: 0.3946 - val_accuracy: 0.9442
# Epoch 47/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0139 - accuracy: 0.9957 - val_loss: 0.5062 - val_accuracy: 0.9365
# Epoch 48/100
# 544/544 [==============================] - 7s 12ms/step - loss: 0.0219 - accuracy: 0.9935 - val_loss: 0.3198 - val_accuracy: 0.9485
# Epoch 49/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0154 - accuracy: 0.9950 - val_loss: 0.4559 - val_accuracy: 0.9431
# Epoch 50/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0141 - accuracy: 0.9959 - val_loss: 0.4957 - val_accuracy: 0.9469
# Epoch 51/100
# 544/544 [==============================] - 7s 14ms/step - loss: 0.0147 - accuracy: 0.9956 - val_loss: 0.4815 - val_accuracy: 0.9456
# Epoch 52/100
# 544/544 [==============================] - 7s 14ms/step - loss: 0.0151 - accuracy: 0.9954 - val_loss: 0.4303 - val_accuracy: 0.9315
# Epoch 53/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0147 - accuracy: 0.9956 - val_loss: 0.5059 - val_accuracy: 0.9367
# Epoch 54/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0169 - accuracy: 0.9950 - val_loss: 0.5032 - val_accuracy: 0.9503
# Epoch 55/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0150 - accuracy: 0.9954 - val_loss: 0.3907 - val_accuracy: 0.9469
# Epoch 56/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0161 - accuracy: 0.9950 - val_loss: 0.4272 - val_accuracy: 0.9449
# Epoch 57/100
# 544/544 [==============================] - 7s 12ms/step - loss: 0.0169 - accuracy: 0.9953 - val_loss: 0.3783 - val_accuracy: 0.9469
# Epoch 58/100
# 544/544 [==============================] - 7s 12ms/step - loss: 0.0119 - accuracy: 0.9964 - val_loss: 0.4290 - val_accuracy: 0.9422
# Epoch 59/100
# 544/544 [==============================] - 7s 12ms/step - loss: 0.0151 - accuracy: 0.9953 - val_loss: 0.4624 - val_accuracy: 0.9408
# Epoch 60/100
# 544/544 [==============================] - 7s 12ms/step - loss: 0.0142 - accuracy: 0.9954 - val_loss: 0.4785 - val_accuracy: 0.9431
# Epoch 61/100
# 544/544 [==============================] - 7s 12ms/step - loss: 0.0142 - accuracy: 0.9957 - val_loss: 0.4860 - val_accuracy: 0.9327
# Epoch 62/100
# 544/544 [==============================] - 7s 12ms/step - loss: 0.0125 - accuracy: 0.9964 - val_loss: 0.4105 - val_accuracy: 0.9429
# Epoch 63/100
# 544/544 [==============================] - 7s 12ms/step - loss: 0.0123 - accuracy: 0.9964 - val_loss: 0.3245 - val_accuracy: 0.9499
# Epoch 64/100
# 544/544 [==============================] - 7s 12ms/step - loss: 0.0153 - accuracy: 0.9957 - val_loss: 0.5472 - val_accuracy: 0.9331
# Epoch 65/100
# 544/544 [==============================] - 7s 12ms/step - loss: 0.0126 - accuracy: 0.9964 - val_loss: 0.4531 - val_accuracy: 0.9451
# Epoch 66/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0132 - accuracy: 0.9958 - val_loss: 0.5430 - val_accuracy: 0.9454
# Epoch 67/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0153 - accuracy: 0.9955 - val_loss: 0.4941 - val_accuracy: 0.9376
# Epoch 68/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0150 - accuracy: 0.9961 - val_loss: 0.5597 - val_accuracy: 0.9404
# Epoch 69/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0159 - accuracy: 0.9955 - val_loss: 0.5025 - val_accuracy: 0.9413
# Epoch 70/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0143 - accuracy: 0.9957 - val_loss: 0.6793 - val_accuracy: 0.9406
# Epoch 71/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0095 - accuracy: 0.9970 - val_loss: 0.5055 - val_accuracy: 0.9476
# Epoch 72/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0158 - accuracy: 0.9957 - val_loss: 0.5941 - val_accuracy: 0.9365
# Epoch 73/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0126 - accuracy: 0.9961 - val_loss: 0.5138 - val_accuracy: 0.9417
# Epoch 74/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0145 - accuracy: 0.9958 - val_loss: 0.5115 - val_accuracy: 0.9279
# Epoch 75/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0155 - accuracy: 0.9959 - val_loss: 0.4554 - val_accuracy: 0.9433
# Epoch 76/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0128 - accuracy: 0.9959 - val_loss: 0.4120 - val_accuracy: 0.9472
# Epoch 77/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0148 - accuracy: 0.9960 - val_loss: 0.3444 - val_accuracy: 0.9515
# Epoch 78/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0106 - accuracy: 0.9971 - val_loss: 0.5168 - val_accuracy: 0.9454
# Epoch 79/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0127 - accuracy: 0.9965 - val_loss: 0.4522 - val_accuracy: 0.9478
# Epoch 80/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0087 - accuracy: 0.9975 - val_loss: 0.7166 - val_accuracy: 0.9302
# Epoch 81/100
# 544/544 [==============================] - 7s 12ms/step - loss: 0.0135 - accuracy: 0.9963 - val_loss: 0.6135 - val_accuracy: 0.9388
# Epoch 82/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0130 - accuracy: 0.9963 - val_loss: 0.5185 - val_accuracy: 0.9347
# Epoch 83/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0188 - accuracy: 0.9953 - val_loss: 0.6607 - val_accuracy: 0.9372
# Epoch 84/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0110 - accuracy: 0.9967 - val_loss: 0.5551 - val_accuracy: 0.9440
# Epoch 85/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0143 - accuracy: 0.9961 - val_loss: 0.5898 - val_accuracy: 0.9426
# Epoch 86/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0108 - accuracy: 0.9968 - val_loss: 0.4581 - val_accuracy: 0.9367
# Epoch 87/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0094 - accuracy: 0.9970 - val_loss: 0.4362 - val_accuracy: 0.9451
# Epoch 88/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0107 - accuracy: 0.9971 - val_loss: 0.4550 - val_accuracy: 0.9415
# Epoch 89/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0117 - accuracy: 0.9966 - val_loss: 0.5144 - val_accuracy: 0.9390
# Epoch 90/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0108 - accuracy: 0.9968 - val_loss: 0.3860 - val_accuracy: 0.9499
# Epoch 91/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0122 - accuracy: 0.9967 - val_loss: 0.4595 - val_accuracy: 0.9410
# Epoch 92/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0137 - accuracy: 0.9966 - val_loss: 0.6624 - val_accuracy: 0.9408
# Epoch 93/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0146 - accuracy: 0.9961 - val_loss: 0.6953 - val_accuracy: 0.9408
# Epoch 94/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0132 - accuracy: 0.9964 - val_loss: 0.5342 - val_accuracy: 0.9476
# Epoch 95/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0108 - accuracy: 0.9970 - val_loss: 0.5286 - val_accuracy: 0.9440
# Epoch 96/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0106 - accuracy: 0.9976 - val_loss: 0.6859 - val_accuracy: 0.9420
# Epoch 97/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0108 - accuracy: 0.9969 - val_loss: 0.4943 - val_accuracy: 0.9490
# Epoch 98/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0107 - accuracy: 0.9974 - val_loss: 0.5608 - val_accuracy: 0.9395
# Epoch 99/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0122 - accuracy: 0.9964 - val_loss: 0.5398 - val_accuracy: 0.9483
# Epoch 100/100
# 544/544 [==============================] - 7s 13ms/step - loss: 0.0110 - accuracy: 0.9972 - val_loss: 0.4037 - val_accuracy: 0.9474

# %%
plt.style.use('seaborn-darkgrid')
palette = plt.get_cmap('Set1')

plt.plot(history.history['val_accuracy'], label='Validation accuracy', color = palette(2))
plt.plot(history.history['accuracy'], label='Train accuracy', color = palette(1))
plt.title("Training Performance")
plt.xlabel("Epoch")
plt.legend()
plt.show()

# %%
# Test
# Can you do better than me?    
predictions = model.evaluate(X_test, y_test)

print ("Test Accuracy = " + str(predictions[1]))
# Out:
# 395/395 [==============================] - 1s 2ms/step - loss: 0.6950 - accuracy: 0.9390
# Test Accuracy = 0.9390340447425842

# %%
from sklearn.metrics import confusion_matrix

predicted_classes = model.predict(X_test)
y_true = y_test

y_pred = np.zeros((y_test.shape[0],y_test.shape[1]))
i = 0
for predicted in predicted_classes:
    y_pred[i][list(predicted).index(max(predicted))] = 1
    i += 1
y_pred = y_pred.astype(int)

cm = confusion_matrix(y_true.argmax(axis=1), y_pred.argmax(axis=1))

cm
# Out:
# 395/395 [==============================] - 1s 2ms/step
# array([[ 57,   2,   0, ...,   0,   0,   0],
#        [  1, 702,   9, ...,   0,   0,   0],
#        [  0,   5, 737, ...,   0,   0,   0],
#        ...,
#        [  0,   0,   0, ...,  88,   0,   0],
#        [  0,   0,   0, ...,   0,  54,   0],
#        [  0,   0,   0, ...,   0,  27,  61]], dtype=int64)

# %%
plt.figure(figsize = (25, 25))
sns.heatmap(cm, annot = True)
# Out:
# <AxesSubplot:>

# %%
# PLOT IMAGES WITH PREDICTED SIGNS
preds = model.predict(X_test)

plt.figure(figsize=(12, 12))
start_index = random.randint(0, 7800)
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    
    pred = np.argmax(preds[start_index+i])
    gt = np.argmax(y_test[start_index+i])
    
    col = 'g'
    if pred != gt:
        col = 'r'
    
    plt.xlabel('i={}, pred={}, gt={}'.format(start_index+i, pred, gt), color=col)
    plt.imshow((X_test[start_index+i]+1.)/2., cmap='gray')
plt.show()
# Out:
# 395/395 [==============================] - 1s 2ms/step

# %% [markdown]
# A validation set can be used to assess how well the model is performing. A low accuracy on the training and validation
# sets imply underfitting. A high accuracy on the training set but low accuracy on the validation set implies overfitting.

# %% [markdown]
# - In this case study, we want to classify images of traffic signs using deep Convolutional Neural Networks (CNNs).
# - The dataset consists of 43 different classes of images.
# - Classes are as listed below:
#   - 0 = Speed limit (20km/h)
#   - 1 = Speed limit (30km/h)
#   - 2 = Speed limit (50km/h)
#   - 3 = Speed limit (60km/h)
#   - 4 = Speed limit (70km/h)
#   - 5 = Speed limit (80km/h)
#   - 6 = End of speed limit (80km/h)
#   - 7 = Speed limit (100km/h)
#   - 8 = Speed limit (120km/h)
#   - 9 = No passing
#   - 10 = No passing for vehicles over 3.5 metric tons
#   - 11 = Right-of-way at the next intersection
#   - 12 = Priority road
#   - 13 = Yield
#   - 14 = Stop
#   - 15 = No vehicles
#   - 16 = Vehicles over 3.5 metric tons prohibited
#   - 17 = No entry
#   - 18 = General caution
#   - 19 = Dangerous curve to the left
#   - 20 = Dangerous curve to the right
#   - 21 = Double curve
#   - 22 = Bumpy road
#   - 23 = Slippery road
#   - 24 = Road narrows on the right
#   - 25 = Road work
#   - 26 = Traffic signals
#   - 27 = Pedestrians
#   - 28 = Children crossing
#   - 29 = Bicycles crossing
#   - 30 = Beware of ice/snow
#   - 31 = Wild animals crossing
#   - 32 = End of all speed and passing limits
#   - 33 = Turn right ahead
#   - 34 = Turn left ahead
#   - 35 = Ahead only
#   - 36 = Go straight or right
#   - 37 = Go straight or left
#   - 38 = Keep right
#   - 39 = Keep left
#   - 40 = Roundabout mandatory
#   - 41 = End of no passing
#   - 42 = End of no passing by vehicles over 3.5 metric tons
#
# - Citation
# J. Stallkamp, M. Schlipsing, J. Salmen, and C. Igel. The German Traffic Sign Recognition Benchmark: A multi-class classification competition. In Proceedings of the IEEE International Joint Conference on Neural Networks, pages 1453–1460. 2011.
# @inproceedings{Stallkamp-IJCNN-2011, author = {Johannes Stallkamp and Marc Schlipsing and Jan Salmen and Christian Igel}, booktitle = {IEEE International Joint Conference on Neural Networks}, title = {The {G}erman {T}raffic {S}ign {R}ecognition {B}enchmark: A multi-class classification competition}, year = {2011}, pages = {1453--1460} }
